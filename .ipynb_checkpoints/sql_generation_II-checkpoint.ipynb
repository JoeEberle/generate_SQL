# %% [markdown]
# # SQL Generation
#
# #### Generates SQL for table creation, sample queries and ETL Processing
#
# The quote from Good Will Hunting (1997) is:
#
# ***"My boy's wicked smart."*** – Morgan O'Mally (played by Casey Affleck)

# %%
first_intallation = False 
if first_intallation: 
    # !pip install --upgrade bottleneck
    # !pip install pipreqs
# pipreqs /path/to/your/project --force    
# !pip install numpy==1.24.3
# !pip install --upgrade numpy

# %%
import os
import schedule
from datetime import datetime
import pandas as pd
import numpy as np
import khutilities.file_manager as fm 
import khutilities.quick_logger as ql 
import khutilities.talking_code as tc 
from docx import Document
from docx.shared import Inches
from IPython.display import Video
import time
import story_board as sb 
from IPython.display import Markdown, display, Image
print(f"Libraries Imported successfully on {datetime.now().date()} at {datetime.now().time()}")
# Out:
# Libraries Imported successfully on 2025-04-07 at 14:04:30.546422

# %% [markdown]
# #### Required Setup Step 0 - Intitiate Configuration Settings and name the overall solution

# %%
import configparser 
config = configparser.ConfigParser()
cfg = config.read('config.ini')  
solution_name = 'sql_generation'

# %% [markdown]
# #### Required Setup Step 0 - Intitiate Logging and debugging

# %%
import logging # built in python library that does not need to be installed 
import khutilities.file_manager as fm 
import khutilities.quick_logger as ql 

global start_stime 
start_time = ql.set_start_time()
logging = ql.create_logger_start(solution_name) 
ql.pvlog('info',f"Process started {solution_name} on Date:{datetime.now().strftime('%m-%d-%Y')} at Time:{datetime.now().strftime('%I:%M:%S %p')} ")
# Out:
# Process started sql_generation on Date:04-07-2025 at Time:02:04:38 PM

# %%
# Create a new Document
report_date_stamp = datetime.now().date()
report_time_stamp = datetime.now().time()
data_story_doc = Document()
data_story_doc.add_heading(f"Data Science Story Board - {solution_name}", level=1)
data_story_doc.add_heading(f"Processed on : {report_date_stamp} at {report_time_stamp}", level=3)

# %%
definition = '''

## SQL Generation 

1. **Create Table**  
2. **SQL Select**  
3. **ETL Process**  

''' 
# Write the solution definitions out to the solution_description.md file
file_name = "generate_sql.md"
with open(file_name, 'w', encoding='utf-8') as f:
    f.write(definition)  # Write the template to the readme.md file

# Display the definition as formatted Markdown in the notebook
display(Markdown(definition))
# Out:
# ## SQL Generation
#
# 1. **Create Table**
# 2. **SQL Select**
# 3. **ETL Process**

# %%
definition = '''



''' 
sb.outmd(definition)

# %%
definition = '''
## SQL Generation 

🔹 SQL Generation will generate various forms of SQL based upon the datas descriptive statistics:

1. ✅ **Create Table** → Adds a **table_name** for the table or dataset.
2. ✅ **SQL Select** → Adds a **column_name** for current column, how pandas named the raw data.
3. ✅ **ETL Process** → Adds a column for the **pandas.dtype**, how pandas inferred the raw data.


''' 
sb.outmd(definition)
# Out:
# ## SQL Generation
#
# 🔹 SQL Generation will generate various forms of SQL based upon the datas descriptive statistics
#
# 1. ✅ **Create Table** → Adds a **table_name** for the table or dataset.
# 2. ✅ **SQL Select** → Adds a **column_name** for current column, how pandas named the raw data.
# 3. ✅ **ETL Process** → Adds a column for the **pandas.dtype**, how pandas inferred the raw data.

# %%
getting_schema_data = True
if getting_schema_data: 
    
    df = pd.read_excel("schema_statistics.xlsx")    # Read the CSV file into a pandas DataFrame
    print(f'The data contains {df.shape[0]} rows and {df.shape[1]} columns of schema data' )
    print(f"The schema contains {df['Table_Name'].nunique()} tables")
    print(f"The schema contains {df['Column_Name'].count()} column names")    
    df_schema_data = df
# Out:
# The data contains 94 rows and 38 columns of schema data
# The schema contains 6 tables
# The schema contains 94 column names

# %%
df_schema_data.columns
# Out:
# Index(['Table_Name', 'Column_Name', 'Column_Number', 'Pandas_Data_Type',
#        'SQL_Data_Type', 'Likely_Primary_Key', 'Likely_Foreign_Key',
#        'Likely_Categorical', 'count', 'mean', 'std', 'min', '25%', '50%',
#        '75%', 'max', 'S_Count', 'S_Missing_Values', 'S_Unique_Values',
#        'S_Most_Frequent', 'S_Mean', 'S_Standard_Deviation', 'S_Variance',
#        'S_Coefficient_of_Variation', 'S_Skewness', 'S_Kurtosis',
#        'Q_1_Lower_Quartile', 'Q_2_Median', 'Q_3_Upper_Quartile',
#        'Q_4_Top_Quartile_Spread', 'P_10_Percentile', 'P_90_Percentile',
#        'S_Interquartile_Range', 'S_Range', 'S_Minimum_Value',
#        'S_Maximum_Value', 'Inferred_Column_Description', 'Pandas_Data_Type.1'],
#       dtype='object')

# %%
def generate_sql_select_all(df_schema, table_name):
    """ SQL select all detail from table
    """

    table_columns = df_schema[df_schema["Table_Name"] == table_name]["Column_Name"] # Filter schema metadata for the specified table
    if table_columns.empty:    # Check if the table exists in the schema
        return f"-- No columns found for table: {table_name}"

    column_list = ",  ".join([f"{col}" for col in table_columns])  # Format column names safely
    sql_query = f"SELECT  {column_list}\nFROM {table_name};"   # Generate the SELECT statement  

    return sql_query

# %%
def generate_sql_count_all(df_schema, table_name):
    """ generate_sql_count_all """ 
    return f"SELECT count(*) FROM {table_name};"

# %%
df_schema_data[['Table_Name', 'Column_Name', 'Column_Number', 'Pandas_Data_Type','S_Most_Frequent']].head()
# Out:
#   Table_Name               Column_Name  Column_Number Pandas_Data_Type  \
# 0   Diabetes                       Age              1            int64
# 1   Diabetes                       BMI              2            int64
# 2   Diabetes             BloodPressure              3            int64
# 3   Diabetes  DiabetesPedigreeFunction              4            int64
# 4   Diabetes                   Glucose              5            int64
#
#   S_Most_Frequent
# 0              22
# 1              32
# 2              70
# 3           0.254
# 4              99

# %%
df_schema_data.columns
# Out:
# Index(['Table_Name', 'Column_Name', 'Column_Number', 'Pandas_Data_Type',
#        'SQL_Data_Type', 'Likely_Primary_Key', 'Likely_Foreign_Key',
#        'Likely_Categorical', 'count', 'mean', 'std', 'min', '25%', '50%',
#        '75%', 'max', 'S_Count', 'S_Missing_Values', 'S_Unique_Values',
#        'S_Most_Frequent', 'S_Mean', 'S_Standard_Deviation', 'S_Variance',
#        'S_Coefficient_of_Variation', 'S_Skewness', 'S_Kurtosis',
#        'Q_1_Lower_Quartile', 'Q_2_Median', 'Q_3_Upper_Quartile',
#        'Q_4_Top_Quartile_Spread', 'P_10_Percentile', 'P_90_Percentile',
#        'S_Interquartile_Range', 'S_Range', 'S_Minimum_Value',
#        'S_Maximum_Value', 'Inferred_Column_Description', 'Pandas_Data_Type.1'],
#       dtype='object')

# %%
def generate_sql_select_all_filter(df_schema, table_name, column_name):
    """ generate_sql_select_all_filter
    """
    # Filter schema metadata for the specified table
    table_columns = df_schema[df_schema["Table_Name"] == table_name]["Column_Name"]

    # Check if the table exists in the schema
    if table_columns.empty:
        return f"-- No columns found for table: {table_name}"

    # Generate the SELECT statement
    column_list = ",  ".join([f"{col}" for col in table_columns])  # Format column names safely
    sql_query = f"SELECT  {column_list}\nFROM {table_name} " 
    sql_query += f"WHERE {column_name} = \n"    

    return sql_query

# %%
def generate_sql_select_count_all_filter(df_schema, table_name, column_name, column_value):
    """
    """
    sql_query = f"SELECT Count(*) \nFROM {table_name} " 
    sql_query += f"WHERE {column_name} = '{column_value}'\n"    

    return sql_query

# %%
import random
def generate_nlp_select_all(df_schema, table_name):
    """
    Generates a SQL Server SELECT statement for a given table based on df_schema.

    Parameters:
    df_schema (pd.DataFrame): The schema metadata DataFrame.
    table_name (str): The name of the table for which to generate the SELECT statement.

    Returns:
    str: The generated natural language question assoicated with the SQL SELECT statement.
    """
    # Generate the NLP question
    question_random = random.randint(1, 9)
    
    if question_random == 1:
        nlp_question = f"Can you show me all the details from the {table_name} table?"
    elif question_random == 2:
        nlp_question = f"What information is stored in the {table_name} table?"
    elif question_random == 3:
        nlp_question = f"Please provide every detail from the {table_name} table."
    elif question_random == 4:
        nlp_question = f"What do you know about {table_name}?"   
    elif question_random == 5:
        nlp_question = f"Can you list everything in the {table_name} table for me?"     
    elif question_random == 6:
        nlp_question = f"What are all the entries stored in the {table_name} table?"    
    elif question_random == 7:
        nlp_question = f"provide examples of {table_name} ?"           
    elif question_random == 8:
        nlp_question = f"show me examples of {table_name} ?"  
    elif question_random == 9:
        nlp_question = f"I need to see all the content of the {table_name}. Could you show that?"          

    return nlp_question

# %%
# Example Usage
table_name = "Diabetes"  # Replace with your desired table name
sql_statement = generate_sql_select_all(df_schema_data, table_name)

print(sql_statement)   # Print SQL statement
# Out:
# SELECT  Age,  BMI,  BloodPressure,  DiabetesPedigreeFunction,  Glucose,  Insulin,  Outcome,  Pregnancies,  SkinThickness
# FROM Diabetes;

# %%
df_schema_data.columns
# Out:
# Index(['Table_Name', 'Column_Name', 'Column_Number', 'Pandas_Data_Type',
#        'SQL_Data_Type', 'Likely_Primary_Key', 'Likely_Foreign_Key',
#        'Likely_Categorical', 'count', 'mean', 'std', 'min', '25%', '50%',
#        '75%', 'max', 'S_Count', 'S_Missing_Values', 'S_Unique_Values',
#        'S_Most_Frequent', 'S_Mean', 'S_Standard_Deviation', 'S_Variance',
#        'S_Coefficient_of_Variation', 'S_Skewness', 'S_Kurtosis',
#        'Q_1_Lower_Quartile', 'Q_2_Median', 'Q_3_Upper_Quartile',
#        'Q_4_Top_Quartile_Spread', 'P_10_Percentile', 'P_90_Percentile',
#        'S_Interquartile_Range', 'S_Range', 'S_Minimum_Value',
#        'S_Maximum_Value', 'Inferred_Column_Description', 'Pandas_Data_Type.1'],
#       dtype='object')

# %%
def generate_sql_select_all(df_schema, table_name):
    return f"SELECT * FROM {table_name};"

def generate_nlp_select_all(df_schema, table_name):
    return f"Show all records from {table_name}."

def generate_sql_select_all_explicit(df_schema, table_name):
    table_columns = df_schema[df_schema["Table_Name"] == table_name]["Column_Name"]
    column_list = ",  ".join([f"{col}" for col in table_columns])  # Format column names safely    
    return f"SELECT {column_list} FROM {table_name};"

def generate_nlp_select_all_explicit(schema, table_name):
    return f"Show detail for all records from {table_name}."

# %%
# Initialize the DataFrame for storing training questions
df_training_questions = pd.DataFrame(columns=['Table_Name', 'SQL_Type', 'SQL_Query', 'NLP_Query'])

# Get unique list of tables from schema data
list_of_tables = df_schema_data.Table_Name.unique()

# Generate SQL and NLP queries for each table
for table_number, table_name in enumerate(list_of_tables):
    print(f"Table#{table_number} - Name:{table_name}")
    
    select_all_sql = generate_sql_select_all(df_schema_data, table_name)
    print(f"Select All SQL: {select_all_sql}")
    
    select_all_nlp = generate_nlp_select_all(df_schema_data, table_name)
    print(f"Select All NLP: {select_all_nlp}")
 
    new_row = pd.DataFrame({
        'Table_Name': [table_name], 
        'SQL_Type': ['select all'], 
        'SQL_Query': [select_all_sql], 
        'NLP_Query': [select_all_nlp]
    })
    df_training_questions = pd.concat([df_training_questions, new_row], ignore_index=True)
# Out:
# Table#0 - Name:Diabetes
# Select All SQL: SELECT * FROM Diabetes;
# Select All NLP: Show all records from Diabetes.
# Table#1 - Name:Health_Care
# Select All SQL: SELECT * FROM Health_Care;
# Select All NLP: Show all records from Health_Care.
# Table#2 - Name:Penguin
# Select All SQL: SELECT * FROM Penguin;
# Select All NLP: Show all records from Penguin.
# Table#3 - Name:Titanic
# Select All SQL: SELECT * FROM Titanic;
# Select All NLP: Show all records from Titanic.
# Table#4 - Name:Personnel
# Select All SQL: SELECT * FROM Personnel;
# Select All NLP: Show all records from Personnel.
# Table#5 - Name:Network_Provider_Patient
# Select All SQL: SELECT * FROM Network_Provider_Patient;
# Select All NLP: Show all records from Network_Provider_Patient.

# %%
df_training_questions.shape
# Out:
# (6, 4)

# %%
df_titanic_columns = df_schema_data[df_schema_data["Table_Name"] == 'Titanic']
df_titanic_columns.head(100)
# Out:
#    Table_Name  Column_Name  Column_Number Pandas_Data_Type SQL_Data_Type  \
# 33    Titanic          Age              1            int64        BIGINT
# 34    Titanic     Age_wiki              2          float64         FLOAT
# 35    Titanic      Boarded              3            int64        BIGINT
# 36    Titanic         Body              4           object  VARCHAR(255)
# 37    Titanic        Cabin              5           object  VARCHAR(255)
# 38    Titanic        Class              6          float64         FLOAT
# 39    Titanic  Destination              7            int64        BIGINT
# 40    Titanic     Embarked              8            int64        BIGINT
# 41    Titanic         Fare              9           object  VARCHAR(255)
# 42    Titanic     Hometown             10          float64         FLOAT
# 43    Titanic     Lifeboat             11           object  VARCHAR(255)
# 44    Titanic         Name             12           object  VARCHAR(255)
# 45    Titanic    Name_wiki             13          float64         FLOAT
# 46    Titanic        Parch             14           object  VARCHAR(255)
# 47    Titanic  PassengerId             15          float64         FLOAT
# 48    Titanic       Pclass             16           object  VARCHAR(255)
# 49    Titanic          Sex             17           object  VARCHAR(255)
# 50    Titanic        SibSp             18           object  VARCHAR(255)
# 51    Titanic     Survived             19           object  VARCHAR(255)
# 52    Titanic       Ticket             20           object  VARCHAR(255)
# 53    Titanic       WikiId             21          float64         FLOAT
#
#     Likely_Primary_Key  Likely_Foreign_Key  Likely_Categorical  count  \
# 33               False               False               False   1046
# 34               False               False               False   1302
# 35               False               False                True   1304
# 36               False               False               False    130
# 37               False               False               False    295
# 38               False               False                True   1304
# 39               False               False               False   1304
# 40               False               False                True   1307
# 41               False               False               False   1308
# 42               False               False               False   1304
# 43               False               False                True    502
# 44               False                True               False   1309
# 45               False                True               False   1304
# 46               False               False                True   1309
# 47                True               False               False   1309
# 48               False               False                True   1309
# 49               False               False                True   1309
# 50               False               False                True   1309
# 51               False               False                True    891
# 52               False                True               False   1309
# 53               False                True               False   1304
#
#           mean  ...  Q_3_Upper_Quartile  Q_4_Top_Quartile_Spread  \
# 33   29.881138  ...              39.000                  41.0000
# 34   29.415829  ...              37.750                  36.2500
# 35         NaN  ...                 NaN                      NaN
# 36         NaN  ...                 NaN                      NaN
# 37         NaN  ...                 NaN                      NaN
# 38    2.291411  ...               3.000                   0.0000
# 39         NaN  ...                 NaN                      NaN
# 40         NaN  ...                 NaN                      NaN
# 41   33.295479  ...              31.275                 481.0542
# 42         NaN  ...                 NaN                      NaN
# 43         NaN  ...                 NaN                      NaN
# 44         NaN  ...                 NaN                      NaN
# 45         NaN  ...                 NaN                      NaN
# 46    0.385027  ...               0.000                   9.0000
# 47  655.000000  ...             982.000                 327.0000
# 48    2.294882  ...               3.000                   0.0000
# 49         NaN  ...                 NaN                      NaN
# 50    0.498854  ...               1.000                   7.0000
# 51    0.383838  ...               1.000                   0.0000
# 52         NaN  ...                 NaN                      NaN
# 53  658.534509  ...             987.250                 326.7500
#
#     P_10_Percentile  P_90_Percentile  S_Interquartile_Range    S_Range  \
# 33          14.0000         50.00000                18.0000    79.8300
# 34          15.0000         48.00000                16.7500    73.8300
# 35              NaN              NaN                    NaN        NaN
# 36              NaN              NaN                    NaN        NaN
# 37              NaN              NaN                    NaN        NaN
# 38           1.0000          3.00000                 1.2500     2.0000
# 39              NaN              NaN                    NaN        NaN
# 40              NaN              NaN                    NaN        NaN
# 41           7.5675         78.05082                23.3792   512.3292
# 42              NaN              NaN                    NaN        NaN
# 43              NaN              NaN                    NaN        NaN
# 44              NaN              NaN                    NaN        NaN
# 45              NaN              NaN                    NaN        NaN
# 46           0.0000          2.00000                 0.0000     9.0000
# 47         131.8000       1178.20000               654.0000  1308.0000
# 48           1.0000          3.00000                 1.0000     2.0000
# 49              NaN              NaN                    NaN        NaN
# 50           0.0000          1.00000                 1.0000     8.0000
# 51           0.0000          1.00000                 1.0000     1.0000
# 52              NaN              NaN                    NaN        NaN
# 53         131.3000       1183.70000               660.5000  1313.0000
#
#                       S_Minimum_Value  S_Maximum_Value  \
# 33                               0.17          80.0000
# 34                               0.17          74.0000
# 35                            Belfast              NaN
# 36                              101MB              NaN
# 37                                A10              NaN
# 38                                  1           3.0000
# 39         Aberdeen, South Dakota, US              NaN
# 40                                  C              NaN
# 41                                  0         512.3292
# 42  Abbeyleix, Laois, Ireland[note 1]              NaN
# 43                                  1              NaN
# 44                Abbing, Mr. Anthony              NaN
# 45                Abbing, Mr. Anthony              NaN
# 46                                  0           9.0000
# 47                                  1        1309.0000
# 48                                  1           3.0000
# 49                             female              NaN
# 50                                  0           8.0000
# 51                                  0           1.0000
# 52                             110152              NaN
# 53                                  1        1314.0000
#
#                           Inferred_Column_Description Pandas_Data_Type.1
# 33  Table Titanic Column Age of type BIGINT and ma...              int64
# 34  Table Titanic Column Age_wiki of type FLOAT an...            float64
# 35  Table Titanic Column Boarded of type BIGINT an...              int64
# 36  Table Titanic Column Body of type VARCHAR(255)...             object
# 37  Table Titanic Column Cabin of type VARCHAR(255...             object
# 38  Table Titanic Column Class of type FLOAT and m...            float64
# 39  Table Titanic Column Destination of type BIGIN...              int64
# 40  Table Titanic Column Embarked of type BIGINT a...              int64
# 41  Table Titanic Column Fare of type VARCHAR(255)...             object
# 42  Table Titanic Column Hometown of type FLOAT an...            float64
# 43  Table Titanic Column Lifeboat of type VARCHAR(...             object
# 44  Table Titanic Column Name of type VARCHAR(255)...             object
# 45  Table Titanic Column Name_wiki of type FLOAT a...            float64
# 46  Table Titanic Column Parch of type VARCHAR(255...             object
# 47  Table Titanic Column PassengerId of type FLOAT...            float64
# 48  Table Titanic Column Pclass of type VARCHAR(25...             object
# 49  Table Titanic Column Sex of type VARCHAR(255) ...             object
# 50  Table Titanic Column SibSp of type VARCHAR(255...             object
# 51  Table Titanic Column Survived of type VARCHAR(...             object
# 52  Table Titanic Column Ticket of type VARCHAR(25...             object
# 53  Table Titanic Column WikiId of type FLOAT and ...            float64
#
# [21 rows x 38 columns]

# %%
df_schema_data.columns

# %%
df_schema_data.head(100)
# Out:
#                   Table_Name               Column_Name  Column_Number  \
# 0                   Diabetes                       Age              1
# 1                   Diabetes                       BMI              2
# 2                   Diabetes             BloodPressure              3
# 3                   Diabetes  DiabetesPedigreeFunction              4
# 4                   Diabetes                   Glucose              5
# ..                       ...                       ...            ...
# 89  Network_Provider_Patient                      RACE             28
# 90  Network_Provider_Patient  SPONSORING_PROVIDER_NAME             29
# 91  Network_Provider_Patient   SPONSORING_PROVIDER_NPI             30
# 92  Network_Provider_Patient                     STATE             31
# 93  Network_Provider_Patient                 YEARS_OLD             32
#
#    Pandas_Data_Type SQL_Data_Type  Likely_Primary_Key  Likely_Foreign_Key  \
# 0             int64        BIGINT               False               False
# 1             int64        BIGINT               False               False
# 2             int64        BIGINT               False               False
# 3             int64        BIGINT               False                True
# 4             int64        BIGINT               False               False
# ..              ...           ...                 ...                 ...
# 89           object  VARCHAR(255)               False               False
# 90           object  VARCHAR(255)               False               False
# 91            int64        BIGINT               False               False
# 92           object  VARCHAR(255)               False               False
# 93           object  VARCHAR(255)               False               False
#
#     Likely_Categorical  count          mean  ...  Q_3_Upper_Quartile  \
# 0                False    768  3.324089e+01  ...        4.100000e+01
# 1                False    768  3.199258e+01  ...        3.660000e+01
# 2                False    768  6.910547e+01  ...        8.000000e+01
# 3                False    768  4.718763e-01  ...        6.262500e-01
# 4                False    768  1.208945e+02  ...        1.402500e+02
# ..                 ...    ...           ...  ...                 ...
# 89                True    967           NaN  ...                 NaN
# 90               False    211           NaN  ...                 NaN
# 91               False    205  1.563360e+09  ...        1.720088e+09
# 92                True    992           NaN  ...                 NaN
# 93               False    992  5.275806e+01  ...        7.200000e+01
#
#     Q_4_Top_Quartile_Spread  P_10_Percentile  P_90_Percentile  \
# 0              4.000000e+01     2.200000e+01     5.100000e+01
# 1              3.050000e+01     2.360000e+01     4.150000e+01
# 2              4.200000e+01     5.400000e+01     8.800000e+01
# 3              1.793750e+00     1.650000e-01     8.786000e-01
# 4              5.875000e+01     8.500000e+01     1.670000e+02
# ..                      ...              ...              ...
# 89                      NaN              NaN              NaN
# 90                      NaN              NaN              NaN
# 91             2.726689e+08     1.229265e+09     1.873633e+09
# 92                      NaN              NaN              NaN
# 93             2.900000e+01     1.900000e+01     7.900000e+01
#
#     S_Interquartile_Range       S_Range                   S_Minimum_Value  \
# 0            1.700000e+01  6.000000e+01                                21
# 1            9.300000e+00  6.710000e+01                                 0
# 2            1.800000e+01  1.220000e+02                                 0
# 3            3.825000e-01  2.342000e+00                             0.078
# 4            4.125000e+01  1.990000e+02                                 0
# ..                    ...           ...                               ...
# 89                    NaN           NaN  American Indian or Alaska Native
# 90                    NaN           NaN
# 91           2.523934e+08  9.894445e+08                        1003312455
# 92                    NaN           NaN                                FL
# 93           3.700000e+01  1.010000e+02                                 0
#
#     S_Maximum_Value                        Inferred_Column_Description  \
# 0      8.100000e+01  Table Diabetes Column Age of type BIGINT and m...
# 1      6.710000e+01  Table Diabetes Column BMI of type BIGINT and m...
# 2      1.220000e+02  Table Diabetes Column BloodPressure of type BI...
# 3      2.420000e+00  Table Diabetes Column DiabetesPedigreeFunction...
# 4      1.990000e+02  Table Diabetes Column Glucose of type BIGINT a...
# ..              ...                                                ...
# 89              NaN  Table Network_Provider_Patient Column RACE of ...
# 90              NaN  Table Network_Provider_Patient Column SPONSORI...
# 91     1.992757e+09  Table Network_Provider_Patient Column SPONSORI...
# 92              NaN  Table Network_Provider_Patient Column STATE of...
# 93     1.010000e+02  Table Network_Provider_Patient Column YEARS_OL...
#
#    Pandas_Data_Type.1
# 0               int64
# 1               int64
# 2               int64
# 3               int64
# 4               int64
# ..                ...
# 89             object
# 90             object
# 91              int64
# 92             object
# 93             object
#
# [94 rows x 38 columns]

# %%
# Generate SQL query for each column in each table based on the most frequent value
for index, row in df_schema_data.iterrows():
    table_name = row['Table_Name']
    column_name = row['Column_Name']
    most_frequent_value = row['S_Most_Frequent']
    
    # Check if the most frequent value is a string and needs to be quoted
    if isinstance(most_frequent_value, str):
        most_frequent_value = f"'{most_frequent_value}'"
    
    # Generate SQL query
    sql_query = f"SELECT COUNT(*) FROM {table_name} WHERE {column_name} = {most_frequent_value};"
    nlp_query = f"HOW MANY RECORDS FROM {table_name} WHERE {column_name} is {most_frequent_value};"
    
    new_row = pd.DataFrame({
        'Table_Name': [table_name], 
        'SQL_Type': ['select count of filter'], 
        'SQL_Query': [sql_query], 
        'NLP_Query': [nlp_query]
    })
    df_training_questions = pd.concat([df_training_questions, new_row], ignore_index=True)

# %%
df_training_questions.shape
# Out:
# (100, 4)

# %%
# Generate SQL query for each column in each table based on the most frequent value
for index, row in df_schema_data.iterrows():
    table_name = row['Table_Name']
    column_name = row['Column_Name']
    likely_categorical = row['Likely_Categorical']
    
    if table_name == 'Titanic' : 
        nlp_column = 'passengers'
        nlp_from_column = 'PassengerId' 
    
    
    if likely_categorical and table_name == 'Titanic' : 
        categories = df_titanic[column_name].unique()
        
        if len(categories) < 10: 
            for category_value in categories:  
    
                if isinstance(category_value, str):
                    category_value = f"'{category_value}'"
                

                # Generate SQL query
                sql_query = f"SELECT COUNT(distinct {nlp_from_column}) FROM {table_name} WHERE {column_name} = {category_value};"
                nlp_query = f"How many {nlp_column} where {column_name} is {category_value};"
    
    new_row = pd.DataFrame({
        'Table_Name': [table_name], 
        'SQL_Type': ['select count of category'], 
        'SQL_Query': [sql_query], 
        'NLP_Query': [nlp_query]
    })
    df_training_questions = pd.concat([df_training_questions, new_row], ignore_index=True)

# %%
df_training_questions.shape
# Out:
# (299, 4)

# %%
df_training_questions.tail(50)
# Out:
#                    Table_Name                  SQL_Type  \
# 249                   Titanic  select count of category
# 250                   Titanic  select count of category
# 251                   Titanic  select count of category
# 252                   Titanic  select count of category
# 253                   Titanic  select count of category
# 254                   Titanic  select count of category
# 255                   Titanic  select count of category
# 256                   Titanic  select count of category
# 257                   Titanic  select count of category
# 258                   Titanic  select count of category
# 259                 Personnel  select count of category
# 260                 Personnel  select count of category
# 261                 Personnel  select count of category
# 262                 Personnel  select count of category
# 263                 Personnel  select count of category
# 264                 Personnel  select count of category
# 265                 Personnel  select count of category
# 266                 Personnel  select count of category
# 267  Network_Provider_Patient  select count of category
# 268  Network_Provider_Patient  select count of category
# 269  Network_Provider_Patient  select count of category
# 270  Network_Provider_Patient  select count of category
# 271  Network_Provider_Patient  select count of category
# 272  Network_Provider_Patient  select count of category
# 273  Network_Provider_Patient  select count of category
# 274  Network_Provider_Patient  select count of category
# 275  Network_Provider_Patient  select count of category
# 276  Network_Provider_Patient  select count of category
# 277  Network_Provider_Patient  select count of category
# 278  Network_Provider_Patient  select count of category
# 279  Network_Provider_Patient  select count of category
# 280  Network_Provider_Patient  select count of category
# 281  Network_Provider_Patient  select count of category
# 282  Network_Provider_Patient  select count of category
# 283  Network_Provider_Patient  select count of category
# 284  Network_Provider_Patient  select count of category
# 285  Network_Provider_Patient  select count of category
# 286  Network_Provider_Patient  select count of category
# 287  Network_Provider_Patient  select count of category
# 288  Network_Provider_Patient  select count of category
# 289  Network_Provider_Patient  select count of category
# 290  Network_Provider_Patient  select count of category
# 291  Network_Provider_Patient  select count of category
# 292  Network_Provider_Patient  select count of category
# 293  Network_Provider_Patient  select count of category
# 294  Network_Provider_Patient  select count of category
# 295  Network_Provider_Patient  select count of category
# 296  Network_Provider_Patient  select count of category
# 297  Network_Provider_Patient  select count of category
# 298  Network_Provider_Patient  select count of category
#
#                                              SQL_Query  \
# 249  SELECT COUNT(*) FROM Titanic WHERE Embarked = ...
# 250  SELECT COUNT(*) FROM Titanic WHERE Embarked = ...
# 251      SELECT COUNT(*) FROM Titanic WHERE Parch = 9;
# 252      SELECT COUNT(*) FROM Titanic WHERE Parch = 9;
# 253     SELECT COUNT(*) FROM Titanic WHERE Pclass = 2;
# 254  SELECT COUNT(*) FROM Titanic WHERE Sex = 'fema...
# 255      SELECT COUNT(*) FROM Titanic WHERE SibSp = 8;
# 256  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 257  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 258  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 259  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 260  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 261  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 262  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 263  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 264  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 265  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 266  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 267  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 268  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 269  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 270  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 271  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 272  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 273  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 274  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 275  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 276  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 277  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 278  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 279  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 280  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 281  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 282  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 283  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 284  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 285  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 286  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 287  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 288  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 289  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 290  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 291  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 292  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 293  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 294  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 295  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 296  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 297  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
# 298  SELECT COUNT(*) FROM Titanic WHERE Survived = ...
#
#                                              NLP_Query
# 249  HOW MANY RECORDS FROM Titanic WHERE Embarked i...
# 250  HOW MANY RECORDS FROM Titanic WHERE Embarked i...
# 251    HOW MANY RECORDS FROM Titanic WHERE Parch is 9;
# 252    HOW MANY RECORDS FROM Titanic WHERE Parch is 9;
# 253   HOW MANY RECORDS FROM Titanic WHERE Pclass is 2;
# 254  HOW MANY RECORDS FROM Titanic WHERE Sex is 'fe...
# 255    HOW MANY RECORDS FROM Titanic WHERE SibSp is 8;
# 256  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 257  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 258  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 259  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 260  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 261  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 262  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 263  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 264  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 265  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 266  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 267  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 268  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 269  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 270  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 271  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 272  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 273  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 274  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 275  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 276  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 277  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 278  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 279  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 280  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 281  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 282  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 283  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 284  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 285  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 286  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 287  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 288  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 289  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 290  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 291  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 292  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 293  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 294  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 295  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 296  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 297  HOW MANY RECORDS FROM Titanic WHERE Survived i...
# 298  HOW MANY RECORDS FROM Titanic WHERE Survived i...

# %%
df_schema_data.head(10)
# Out:
#     Table_Name               Column_Name  Column_Number Pandas_Data_Type  \
# 0     Diabetes                       Age              1            int64
# 1     Diabetes                       BMI              2            int64
# 2     Diabetes             BloodPressure              3            int64
# 3     Diabetes  DiabetesPedigreeFunction              4            int64
# 4     Diabetes                   Glucose              5            int64
# 5     Diabetes                   Insulin              6          float64
# 6     Diabetes                   Outcome              7          float64
# 7     Diabetes               Pregnancies              8            int64
# 8     Diabetes             SkinThickness              9            int64
# 9  Health_Care            Admission Type              1           object
#
#   SQL_Data_Type  Likely_Primary_Key  Likely_Foreign_Key  Likely_Categorical  \
# 0        BIGINT               False               False               False
# 1        BIGINT               False               False               False
# 2        BIGINT               False               False               False
# 3        BIGINT               False                True               False
# 4        BIGINT               False               False               False
# 5         FLOAT               False               False               False
# 6         FLOAT               False               False                True
# 7        BIGINT               False               False                True
# 8        BIGINT               False               False               False
# 9  VARCHAR(255)               False               False                True
#
#    count        mean  ...  Q_3_Upper_Quartile  Q_4_Top_Quartile_Spread  \
# 0    768   33.240885  ...            41.00000                 40.00000
# 1    768   31.992578  ...            36.60000                 30.50000
# 2    768   69.105469  ...            80.00000                 42.00000
# 3    768    0.471876  ...             0.62625                  1.79375
# 4    768  120.894531  ...           140.25000                 58.75000
# 5    768   79.799479  ...           127.25000                718.75000
# 6    768    0.348958  ...             1.00000                  0.00000
# 7    768    3.845052  ...             6.00000                 11.00000
# 8    768   20.536458  ...            32.00000                 67.00000
# 9  55500         NaN  ...                 NaN                      NaN
#
#    P_10_Percentile  P_90_Percentile  S_Interquartile_Range  S_Range  \
# 0           22.000          51.0000                17.0000   60.000
# 1           23.600          41.5000                 9.3000   67.100
# 2           54.000          88.0000                18.0000  122.000
# 3            0.165           0.8786                 0.3825    2.342
# 4           85.000         167.0000                41.2500  199.000
# 5            0.000         210.0000               127.2500  846.000
# 6            0.000           1.0000                 1.0000    1.000
# 7            0.000           9.0000                 5.0000   17.000
# 8            0.000          40.0000                32.0000   99.000
# 9              NaN              NaN                    NaN      NaN
#
#    S_Minimum_Value  S_Maximum_Value  \
# 0               21            81.00
# 1                0            67.10
# 2                0           122.00
# 3            0.078             2.42
# 4                0           199.00
# 5                0           846.00
# 6                0             1.00
# 7                0            17.00
# 8                0            99.00
# 9         Elective              NaN
#
#                          Inferred_Column_Description Pandas_Data_Type.1
# 0  Table Diabetes Column Age of type BIGINT and m...              int64
# 1  Table Diabetes Column BMI of type BIGINT and m...              int64
# 2  Table Diabetes Column BloodPressure of type BI...              int64
# 3  Table Diabetes Column DiabetesPedigreeFunction...              int64
# 4  Table Diabetes Column Glucose of type BIGINT a...              int64
# 5  Table Diabetes Column Insulin of type FLOAT an...            float64
# 6  Table Diabetes Column Outcome of type FLOAT an...            float64
# 7  Table Diabetes Column Pregnancies of type BIGI...              int64
# 8  Table Diabetes Column SkinThickness of type BI...              int64
# 9  Table Health_Care Column Admission Type of typ...             object
#
# [10 rows x 38 columns]

# %%
df_training_questions.head(100)
# Out:
#                   Table_Name                SQL_Type  \
# 0                   Diabetes              select all
# 1                Health_Care              select all
# 2                    Penguin              select all
# 3                    Titanic              select all
# 4                  Personnel              select all
# ..                       ...                     ...
# 95  Network_Provider_Patient  select count of filter
# 96  Network_Provider_Patient  select count of filter
# 97  Network_Provider_Patient  select count of filter
# 98  Network_Provider_Patient  select count of filter
# 99  Network_Provider_Patient  select count of filter
#
#                                             SQL_Query  \
# 0                             SELECT * FROM Diabetes;
# 1                          SELECT * FROM Health_Care;
# 2                              SELECT * FROM Penguin;
# 3                              SELECT * FROM Titanic;
# 4                            SELECT * FROM Personnel;
# ..                                                ...
# 95  SELECT COUNT(*) FROM Network_Provider_Patient ...
# 96  SELECT COUNT(*) FROM Network_Provider_Patient ...
# 97  SELECT COUNT(*) FROM Network_Provider_Patient ...
# 98  SELECT COUNT(*) FROM Network_Provider_Patient ...
# 99  SELECT COUNT(*) FROM Network_Provider_Patient ...
#
#                                             NLP_Query
# 0                     Show all records from Diabetes.
# 1                  Show all records from Health_Care.
# 2                      Show all records from Penguin.
# 3                      Show all records from Titanic.
# 4                    Show all records from Personnel.
# ..                                                ...
# 95  HOW MANY RECORDS FROM Network_Provider_Patient...
# 96  HOW MANY RECORDS FROM Network_Provider_Patient...
# 97  HOW MANY RECORDS FROM Network_Provider_Patient...
# 98  HOW MANY RECORDS FROM Network_Provider_Patient...
# 99  HOW MANY RECORDS FROM Network_Provider_Patient...
#
# [100 rows x 4 columns]

# %%
df_titanic = pd.read_csv('titanic.csv')

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...        S  691.0
# 1      0          PC 17599  71.2833  ...        C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3      0            113803  53.1000  ...        S  127.0
# 4      0            373450   8.0500  ...        S  627.0
#
#                                     Name_wiki Age_wiki  \
# 0                     Braund, Mr. Owen Harris     22.0
# 1  Cumings, Mrs. Florence Briggs (née Thayer)     35.0
# 2                       Heikkinen, Miss Laina     26.0
# 3          Futrelle, Mrs. Lily May (née Peel)     35.0
# 4                    Allen, Mr. William Henry     35.0
#
#                              Hometown      Boarded  \
# 0          Bridgerule, Devon, England  Southampton
# 1              New York, New York, US    Cherbourg
# 2                  Jyväskylä, Finland  Southampton
# 3         Scituate, Massachusetts, US  Southampton
# 4  Birmingham, West Midlands, England  Southampton
#
#                                Destination Lifeboat Body Class
# 0  Qu'Appelle Valley, Saskatchewan, Canada      NaN  NaN   3.0
# 1                   New York, New York, US        4  NaN   1.0
# 2                            New York City      14?  NaN   3.0
# 3              Scituate, Massachusetts, US        D  NaN   1.0
# 4                            New York City      NaN  NaN   3.0
#
# [5 rows x 21 columns]

# %%
def add_category_filters(table_name)

# Initialize an empty DataFrame to store SQL and NLP queries
df_training_questions = pd.DataFrame(columns=['Table_Name', 'SQL_Type', 'SQL_Query', 'NLP_Query'])

# Process each row in schema data to generate queries
for index, row in df_schema_data.iterrows():
    if row['Likely_Categorical'] == True:  # Adjusted for Boolean True
        table_name = row['Table_Name']
        column_name = row['Column_Name']
        num_unique = unique_counts[table_name].get(column_name, 0)

        if num_unique <= 10:
            # Construct the SQL query
            sql_query = f"SELECT COUNT(*) FROM {table_name} WHERE {column_name} = '{row['S_Most_Frequent']}'"
            nlp_query = f"How many records from {table_name} where {column_name} = '{row['S_Most_Frequent']}'?"

            # Append to the DataFrame
            new_row = pd.DataFrame({
                'Table_Name': [table_name], 
                'SQL_Type': ['select count of filter'], 
                'SQL_Query': [sql_query], 
                'NLP_Query': [nlp_query]
            })
            df_training_questions = pd.concat([df_training_questions, new_row], ignore_index=True)

# Display the resulting DataFrame
print(df_training_questions)
# Out:
#   Table_Name                SQL_Type  \
# 0     table1  select count of filter
# 1     table2  select count of filter
# 2     table2  select count of filter
#
#                                            SQL_Query  \
# 0  SELECT COUNT(*) FROM table1 WHERE category1 = ...
# 1  SELECT COUNT(*) FROM table2 WHERE category1 = ...
# 2  SELECT COUNT(*) FROM table2 WHERE category2 = 'B'
#
#                                            NLP_Query
# 0  How many records from table1 where category1 =...
# 1  How many records from table2 where category1 =...
# 2  How many records from table2 where category2 =...

# %%
import pandas as pd

# Sample schema data
df_schema_data = pd.DataFrame({
    'Table_Name': ['table1', 'table1', 'table2', 'table2'],
    'Column_Name': ['category1', 'category2', 'category1', 'category2'],
    'Likely_Categorical': [True, False, True, True],  # Now using Boolean True/False
    'S_Most_Frequent': [10, 'A', 20, 'B']  # Assuming these are the most frequent values for demonstration
})

# Sample actual data unique counts (simulated here, replace with actual data fetching logic)
unique_counts = {
    'table1': {'category1': 8, 'category2': 15},
    'table2': {'category1': 10, 'category2': 9}
}

# Initialize an empty DataFrame to store SQL and NLP queries
df_training_questions = pd.DataFrame(columns=['Table_Name', 'SQL_Type', 'SQL_Query', 'NLP_Query'])

# Process each row in schema data to generate queries
for index, row in df_schema_data.iterrows():
    if row['Likely_Categorical'] == True:  # Adjusted for Boolean True
        table_name = row['Table_Name']
        column_name = row['Column_Name']
        num_unique = unique_counts[table_name].get(column_name, 0)

        if num_unique <= 10:
            # Construct the SQL query
            sql_query = f"SELECT COUNT(*) FROM {table_name} WHERE {column_name} = '{row['S_Most_Frequent']}'"
            nlp_query = f"How many records from {table_name} where {column_name} = '{row['S_Most_Frequent']}'?"

            # Append to the DataFrame
            new_row = pd.DataFrame({
                'Table_Name': [table_name], 
                'SQL_Type': ['select count of filter'], 
                'SQL_Query': [sql_query], 
                'NLP_Query': [nlp_query]
            })
            df_training_questions = pd.concat([df_training_questions, new_row], ignore_index=True)

# Display the resulting DataFrame
print(df_training_questions)

# %%
df_training_questions = pd.dataframe([['Table_Name','SQL_Type','SQL_Query','NLP_Query']])
list_of_tables = df_schema_data.Table_Name.unique()
for table_number, table_name in enumerate(list_of_tables):
    print(f"Table#{table_number} - Name:{table_name}  ")
    select_all = generate_sql_select_all(df_schema_data, table_name)
    print(f"Select All SQL : {select_all} \n")
    select_all_nlp = generate_nlp_select_all(df_schema_data, table_name)
    df_training_questions.loc = table_name, "select all", select_all, select_all_nlp
    print(f"Select All NLP : {select_all_nlp} \n ")  
    
    
    select_count_all = generate_sql_count_all(df_schema_data, table_name)  
    print(f"Select Count All : {select_count_all} \n ")
    select_all = generate_sql_count_all(df_schema_data, table_name)
# Out:
# Table#0 - Name:Diabetes
# Select All SQL : SELECT    Age,  BMI,  BloodPressure,  DiabetesPedigreeFunction,  Glucose,  Insulin,  Outcome,  Pregnancies,  SkinThickness
# FROM Diabetes;
#
# Select All NLP : What information is stored in the Diabetes table?
#
# Select Count All : SELECT count(*) FROM Diabetes;
#
# Table#1 - Name:Health_Care
# Select All SQL : SELECT    Admission Type,  Age,  Billing Amount,  Blood Type,  Date of Admission,  Discharge Date,  Doctor,  Gender,  Hospital,  Insurance Provider,  Medical Condition,  Medication,  Name,  Room Number,  Test Results
# FROM Health_Care;
#
# Select All NLP : Please provide every detail from the Health_Care table.
#
# Select Count All : SELECT count(*) FROM Health_Care;
#
# Table#2 - Name:Penguin
# Select All SQL : SELECT    Unnamed: 0,  bill_depth_mm,  bill_length_mm,  body_mass_g,  flipper_length_mm,  island,  sex,  species,  year
# FROM Penguin;
#
# Select All NLP : Can you list everything in the Penguin table for me?
#
# Select Count All : SELECT count(*) FROM Penguin;
#
# Table#3 - Name:Titanic
# Select All SQL : SELECT    Age,  Age_wiki,  Boarded,  Body,  Cabin,  Class,  Destination,  Embarked,  Fare,  Hometown,  Lifeboat,  Name,  Name_wiki,  Parch,  PassengerId,  Pclass,  Sex,  SibSp,  Survived,  Ticket,  WikiId
# FROM Titanic;
#
# Select All NLP : Please provide every detail from the Titanic table.
#
# Select Count All : SELECT count(*) FROM Titanic;
#
# Table#4 - Name:Personnel
# Select All SQL : SELECT    ACTIVE_IND,  FAMILY_NAME,  GIVEN_NAME,  MINISTRY_PRSNL_ID,  PART_KEY,  PRSNL_ID,  PRSNL_NAME,  VERSION
# FROM Personnel;
#
# Select All NLP : I need to see all the content of the Personnel. Could you show that?
#
# Select Count All : SELECT count(*) FROM Personnel;
#
# Table#5 - Name:Network_Provider_Patient
# Select All SQL : SELECT    ADDRESS_LINE_1,  ADDRESS_LINE_2,  AGE,  BENEFIT_TYPE,  BENEFIT_TYPE_CODE,  BENEFIT_TYPE_DISPLAY,  BIRTH_DATE,  CITY,  DECEASED,  DECEASED_DATE,  EMAIL_ADDRESS,  ETHNICITY,  GENDER,  MEMBER_ID,  NETWORK,  PATIENT_ID,  PATIENT_LATITUDE,  PATIENT_LONGITUDE,  PATIENT_NAME,  PAYER_NAME,  PHONE_NUMBER,  PLAN_NAME,  POSTAL_CD,  PRACTICE_LOCATION,  PREFERRED_LANGUAGE,  PROVIDER_NAME,  PROVIDER_NPI,  RACE,  SPONSORING_PROVIDER_NAME,  SPONSORING_PROVIDER_NPI,  STATE,  YEARS_OLD
# FROM Network_Provider_Patient;
#
# Select All NLP : Can you show me all the details from the Network_Provider_Patient table?
#
# Select Count All : SELECT count(*) FROM Network_Provider_Patient;

# %%
df_schema_data = pd.read_excel("schema_statistics.xlsx")
print(f"read schema data and found statistics on {df_schema_data.Table_Name.nunique()} tables")
# Out:
# read schema data and found statistics on 6 tables

# %%
table = df_schema_data.Table_Name.unique()
df_schema_data.head(2)
# Out:
#   Table_Name Column_Name  Column_Number Pandas_Data_Type SQL_Data_Type  \
# 0   Diabetes         Age              1            int64        BIGINT
# 1   Diabetes         BMI              2            int64        BIGINT
#
#    Likely_Primary_Key  Likely_Foreign_Key  Likely_Categorical  count  \
# 0               False               False               False    768
# 1               False               False               False    768
#
#         mean  ...  Q_3_Upper_Quartile  Q_4_Top_Quartile_Spread  \
# 0  33.240885  ...                41.0                     40.0
# 1  31.992578  ...                36.6                     30.5
#
#    P_10_Percentile  P_90_Percentile  S_Interquartile_Range  S_Range  \
# 0             22.0             51.0                   17.0     60.0
# 1             23.6             41.5                    9.3     67.1
#
#    S_Minimum_Value  S_Maximum_Value  \
# 0               21             81.0
# 1                0             67.1
#
#                          Inferred_Column_Description Pandas_Data_Type.1
# 0  Table Diabetes Column Age of type BIGINT and m...              int64
# 1  Table Diabetes Column BMI of type BIGINT and m...              int64
#
# [2 rows x 38 columns]

# %%
import os
report_date_stamp = datetime.now().date()
word_file_path = os.path.join(f"{solution_name}_{report_date_stamp}_storyboard.docx")
data_story_doc.save(word_file_path)    
ql.pvlog('info',f"Storyboard Created : {solution_name} ")

# %% [markdown]
# ## Step 0 - Process End - display log

# %%
# Calculate and classify the process performance 
status = ql.calculate_process_performance(solution_name, start_time) 
print(ql.append_log_file(solution_name))

# %% [markdown]
# #### https://github.com/JoeEberle/ -- josepheberle@outlook.com
